# %%
import altair as alt
import pandas as pd

# %%
spec = {
    "config": {
        "view": {
            "continuousWidth": 300,
            "continuousHeight": 300
        }
    },
    "hconcat": [
        {
            "data": {
                "url": "altair-data-afcb77b974a81a42a1cd3c349eb1ffa7.json",
                "format": {
                    "type": "json"
                }
            },
            "mark": {
                "type": "bar"
            },
            "encoding": {
                "color": {
                    "field": "COMPLAINT TYPE",
                    "scale": {
                        "scheme": "category20"
                    },
                    "type": "nominal"
                },
                "tooltip": [
                    {
                        "field": "COMPLAINT TYPE",
                        "type": "nominal"
                    }
                ],
                "x": {
                    "field": "INSPECTOR",
                    "title": "Inspector",
                    "type": "nominal"
                },
                "y": {
                    "field": "COUNT",
                    "title": "Number of Complaints",
                    "type": "quantitative"
                }
            },
            "height": 400,
            "name": "view_9",
            "title": "Top 10 Inspectors for Selected Complaint",
            "width": 500
        },
        {
            "data": {
                "url": "altair-data-05a75c49af1b4bf5d73dcae9fda24fb9.json",
                "format": {
                    "type": "json"
                }
            },
            "mark": {
                "type": "circle",
                "size": 120
            },
            "encoding": {
                "color": {
                    "field": "community",
                    "scale": {
                        "scheme": "category20"
                    },
                    "type": "nominal"
                },
                "tooltip": [
                    {
                        "field": "INSPECTOR",
                        "type": "nominal"
                    },
                    {
                        "field": "COUNT",
                        "type": "quantitative"
                    },
                    {
                        "field": "community",
                        "type": "nominal"
                    }
                ],
                "x": {
                    "field": "COMPLAINT YEAR",
                    "type": "nominal"
                },
                "y": {
                    "field": "COUNT",
                    "type": "quantitative"
                }
            },
            "height": 400,
            "name": "view_10",
            "title": "Inspector Complaints by Year (use tool-tip to identify inspector!)",
            "transform": [
                {
                    "filter": {
                        "param": "param_20",
                        "empty": True
                    }
                }
            ],
            "width": 400
        }
    ],
    "params": [
        {
            "name": "param_17",
            "select": {
                "type": "point",
                "fields": [
                    "latitude_centroid",
                    "longitude_centroid"
                ],
                "on": "click"
            },
            "views": [
                "view_9",
                "view_10"
            ]
        },
        {
            "name": "param_18",
            "select": {
                "type": "point",
                "fields": [
                    "COMPLAINT TYPE"
                ],
                "on": "click"
            },
            "views": [
                "view_9",
                "view_10"
            ]
        },
        {
            "name": "param_19",
            "select": {
                "type": "point",
                "fields": [
                    "INSPECTOR"
                ],
                "on": "click"
            },
            "views": [
                "view_9",
                "view_10"
            ]
        },
        {
            "name": "param_20",
            "select": {
                "type": "point",
                "fields": [
                    "INSPECTOR"
                ],
                "on": "click"
            },
            "views": [
                "view_9"
            ]
        }
    ],
    "$schema": "https://vega.github.io/schema/vega-lite/v5.15.1.json"
}

display(alt.display.html_renderer(spec), raw=True)
# Out:
# <style>
#   #altair-viz-d9e3b3a5b88d4c3581739ed221f09fd5.vega-embed {
#     width: 100%;
#     display: flex;
#   }
#
#   #altair-viz-d9e3b3a5b88d4c3581739ed221f09fd5.vega-embed details,
#   #altair-viz-d9e3b3a5b88d4c3581739ed221f09fd5.vega-embed details summary {
#     position: relative;
#   }
# </style>
# <div id="altair-viz-d9e3b3a5b88d4c3581739ed221f09fd5"></div>
# <script type="text/javascript">
#   var VEGA_DEBUG = (typeof VEGA_DEBUG == "undefined") ? {} : VEGA_DEBUG;
#   (function(spec, embedOpt){
#     let outputDiv = document.currentScript.previousElementSibling;
#     if (outputDiv.id !== "altair-viz-d9e3b3a5b88d4c3581739ed221f09fd5") {
#       outputDiv = document.getElementById("altair-viz-d9e3b3a5b88d4c3581739ed221f09fd5");
#     }
#     const paths = {
#       "vega": "https://cdn.jsdelivr.net/npm/vega@5?noext",
#       "vega-lib": "https://cdn.jsdelivr.net/npm/vega-lib?noext",
#       "vega-lite": "https://cdn.jsdelivr.net/npm/vega-lite@5.15.1?noext",
# ...
